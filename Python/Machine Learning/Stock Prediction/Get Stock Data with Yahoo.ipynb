# %%
#Import the libraries
import math
import pandas_datareader as pdr
import numpy as np
import pandas as pd
import datetime

# %%
df = pd.read_excel("Nifty 500.xlsx")

# %%
df = df[df['Volume']>500000]
df.head()
# Out:
#        Ticker     LTP    Open    High     Low  Prev Close     Volume    Buy  \
# 0        IDEA    9.10    9.00    9.20    8.80        8.85  418346262  False
# 1  TATAMOTORS  123.35  119.95  124.70  119.70      119.10   71095910  False
# 2         BEL  108.25  105.45  113.90  104.40       99.20   65821856  False
# 3        BHEL   36.35   36.00   37.65   35.85       35.25   60898741  False
# 4       CIPLA  797.70  760.00  814.50  751.35      728.65   56895564  False
#
#     Sell  % Change
# 0  False      2.82
# 1  False      3.57
# 2  False      9.12
# 3  False      3.12
# 4  False      9.48

# %%
df.tail()
# Out:
#          Ticker    LTP    Open    High     Low  Prev Close  Volume    Buy  \
# 283  SUDARSCHEM  436.0  438.00  445.00  426.35      448.50  513932  False
# 284    GODREJCP  683.9  691.20  696.35  680.20      689.10  512185  False
# 285  ADVENZYMES  211.0  215.00  215.00  207.75      216.70  510975  False
# 286        IIFL   69.0   69.50   70.60   68.20       68.95  509679  False
# 287         OIL   95.5   95.15   97.00   95.15       94.85  505205   True
#
#       Sell  % Change
# 283  False     -2.79
# 284  False     -0.75
# 285   True     -2.63
# 286  False      0.07
# 287  False      0.69

# %%
# stocks = pd.DataFrame()
for i in df["Ticker"]:
    try:
        stock = pdr.DataReader(i+".NS", data_source='yahoo', start='2000-01-01', end='2021-02-24')
#         stock['Stock'] = i
#         stocks = stocks.append(stock)
        stock.to_excel(f"Nifty500HistoricalStocks/{i}.xlsx")
    except:
        print(i+": No Data")
# stocks.set_index('Stock', inplace=True)
# Out:
# JUBILANT: No Data

# %%
stock = pdr.DataReader("IIFL.NS", data_source='yahoo', start='2000-01-01', end='2021-02-24')

# %%
i = 'IIFL'

# %%
stock.to_excel(f"Nifty500HistoricalStocks/{i}.xlsx")

# %%
pdr.DataReader("IIFL.NS", data_source='yahoo', start='2000-01-01', end='2021-02-24')
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-2-006b7909c0a9> in <module>
# ----> 1 pdr.DataReader("IIFL.NS", data_source='yahoo', start='2000-01-01', end='2021-02-24')
#
# ~\anaconda3\envs\env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\envs\env\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     374
#     375     if data_source == "yahoo":
# --> 376         return YahooDailyReader(
#     377             symbols=name,
#     378             start=start,
#
# ~\anaconda3\envs\env\lib\site-packages\pandas_datareader\base.py in read(self)
# ...

# %%
# Close = High
stocks0508[stocks0508['Close']==stocks0508['High']]['Volume'].sort_values(ascending=False)
# Out:
# Stock
# DISHTV       8728999
# HFCL         4010664
# HATHWAY      1151893
# KPITTECH     1041975
# VAKRANGEE     493342
# VARROC        263260
# Name: Volume, dtype: int64

# %%
# Open = Low
stocks0508[stocks0508['Open']==stocks0508['Low']]['Volume'].sort_values(ascending=False)
# Out:
# Stock
# TATASTEEL     30559741
# NATIONALUM    29447675
# SOUTHBANK     17518892
# NCC           14088804
# GRANULES       9125048
# TATASTLBSL     5893051
# CDSL           2108622
# RAIN           1581793
# ENGINERSIN     1547447
# JSLHISAR       1541797
# CYIENT         1409063
# BALRAMCHIN     1192768
# SCI            1153710
# NAUKRI         1102586
# OMAXE          1087895
# KPITTECH       1041975
# J&KBANK         875843
# AEGISCHEM       748212
# TATAELXSI       706865
# JSL             699395
# NIACL           648949
# CESC            508666
# VAKRANGEE       493342
# LTI             373103
# AJANTPHARM      334303
# POLYCAB         295975
# GREAVESCOT      255098
# TIMETECHNO      203721
# EMAMILTD        135704
# LALPATHLAB       98129
# TVTODAY          85223
# MAHSEAMLES       84836
# AFFLE            59372
# TEAMLEASE        56405
# CGCL             40101
# LINDEINDIA       21689
# PGHL             11774
# VTL              11544
# BHARATRAS         9881
# ...

# %%
today
# Out:
# '2021-01-21'

# %%
twentyyearsago
# Out:
# '2001-01-26'

# %%
# from datetime import datetime
# Out:
# '2021-01-21'

# %%
datetime.now()
# Out:
# datetime.datetime(2021, 1, 21, 12, 14, 42, 238715)

# %%
twentyYearsAgo = datetime.datetime.now() - datetime.timedelta(days=20*365)
twentyYearsAgo = twentyYearsAgo.strftime('%Y-%m-%d')
today = datetime.datetime.today().strftime('%Y-%m-%d')

df = pdr.DataReader("ZEEL.NS", data_source='yahoo', start=twentyYearsAgo, end=today)

# %%
df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2002-07-01  39.138096  38.481468  38.847958  38.878498   4031528.0  33.182491
# 2002-07-02  40.115402  38.542549  38.725796  39.214447  14152321.0  33.469227
# 2002-07-03  39.764183  38.863228  39.031200  39.565666   8456844.0  33.769001
# 2002-07-04  40.833111  39.306068  39.871075  39.535126  12745157.0  33.742931
# 2002-07-05  40.008511  39.015930  40.008511  39.351879   6445895.0  33.586536

# %%
df.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-01-15  233.600006  221.600006  229.000000  224.899994  18690401.0
# 2021-01-18  225.899994  214.350006  225.899994  218.000000  13959600.0
# 2021-01-19  226.949997  220.300003  221.000000  225.050003  11383216.0
# 2021-01-20  231.300003  223.750000  224.800003  228.600006  10865893.0
# 2021-01-21  233.899994  228.100006  230.399994  230.199997   5639882.0
#
#              Adj Close
# Date
# 2021-01-15  224.899994
# 2021-01-18  218.000000
# 2021-01-19  225.050003
# 2021-01-20  228.600006
# 2021-01-21  230.199997

# %%
pdr.DataReader("^CRSLDX", data_source='yahoo', start="2020-12-25", end="2020-12-25")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-1637bafef03d> in <module>
# ...

# %%
# # importing the libraries
# from bs4 import BeautifulSoup
# import requests

# url="https://www.nseindia.com/get-quotes/equity?symbol=SAIL"

# # Make a GET request to fetch the raw HTML content
# html_content = requests.get(url).text

# # Parse the html content
# soup = BeautifulSoup(html_content, "lxml")
# print(soup.prettify()) # print the parsed data of html

# %%
df = pd.read_csv('MW-NIFTY-MIDSMALLCAP-400-11-Aug-2020.csv')

# %%
df
# Out:
#                  SYMBOL \n   OPEN \n   HIGH \n    LOW \n PREV. CLOSE \n  \
# 0    NIFTY MIDSMALLCAP 400  5,593.85  5,626.90  5,591.80       5,542.85
# 1                 EMAMILTD    265.00    308.75    265.00         257.30
# 2                     HFCL     14.40     17.15     14.40          14.30
# 3               HIMATSEIDE     74.75     85.40     73.80          73.35
# 4                     STAR    527.00    616.00    527.00         523.80
# ..                     ...       ...       ...       ...            ...
# 396                  AMBER  1,700.00  1,779.00  1,675.45       1,779.20
# 397              JAMNAAUTO     34.40     34.40     31.85          33.95
# 398                HATHWAY     37.70     37.70     37.70          39.65
# 399                RBLBANK    190.75    193.30    180.10         191.30
# 400             BIRLACORPN    635.10    635.10    600.00         653.10
#
#        LTP \n CHNG \n %CHNG \n  VOLUME \n(shares)              VALUE   \
# ...

# %%
#!/usr/bin/python3
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import requests
import re

_URL = 'https://kissanime.ru/'

# functional
html = requests.get(_URL, headers={"user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Safari/537.36"})
bsObj = soup(html.text, "lxml")
print(bsObj)
